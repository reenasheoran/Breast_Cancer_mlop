# %%
import os
import pandas as pd
df = pd.read_csv('../data/filtered/BreastCancer.csv')
df.head()
# Out:
#    radius_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0        17.99           0.27760          0.3001              0.14710
# 1        20.57           0.07864          0.0869              0.07017
# 2        19.69           0.15990          0.1974              0.12790
# 3        11.42           0.28390          0.2414              0.10520
# 4        20.29           0.13280          0.1980              0.10430
#
#    radius_se  compactness_worst  concavity_worst  concave points_worst  \
# 0     1.0950             0.6656           0.7119                0.2654
# 1     0.5435             0.1866           0.2416                0.1860
# 2     0.7456             0.4245           0.4504                0.2430
# 3     0.4956             0.8663           0.6869                0.2575
# 4     0.7572             0.2050           0.4000                0.1625
#
#    diagnosis
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
df.columns
# Out:
# Index(['radius_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'radius_se', 'compactness_worst',
#        'concavity_worst', 'concave points_worst', 'diagnosis'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                       count       mean       std      min       25%       50%  \
# radius_mean           569.0  14.127292  3.524049  6.98100  11.70000  13.37000
# compactness_mean      569.0   0.104341  0.052813  0.01938   0.06492   0.09263
# concavity_mean        569.0   0.088799  0.079720  0.00000   0.02956   0.06154
# concave points_mean   569.0   0.048919  0.038803  0.00000   0.02031   0.03350
# radius_se             569.0   0.405172  0.277313  0.11150   0.23240   0.32420
# compactness_worst     569.0   0.254265  0.157336  0.02729   0.14720   0.21190
# concavity_worst       569.0   0.272188  0.208624  0.00000   0.11450   0.22670
# concave points_worst  569.0   0.114606  0.065732  0.00000   0.06493   0.09993
# diagnosis             569.0   0.372583  0.483918  0.00000   0.00000   0.00000
#
#                           75%      max
# radius_mean           15.7800  28.1100
# compactness_mean       0.1304   0.3454
# concavity_mean         0.1307   0.4268
# ...

# %%
Range=df.describe().loc[["min", "max"]].to_json("schema_in.json")

# %%
Range
# Out:
# {'radius_mean': {'min': 6.981, 'max': 28.11},
#  'compactness_mean': {'min': 0.01938, 'max': 0.3454},
#  'concavity_mean': {'min': 0.0, 'max': 0.4268},
#  'concave points_mean': {'min': 0.0, 'max': 0.2012},
#  'radius_se': {'min': 0.1115, 'max': 2.873},
#  'compactness_worst': {'min': 0.02729, 'max': 1.058},
#  'concavity_worst': {'min': 0.0, 'max': 1.252},
#  'concave points_worst': {'min': 0.0, 'max': 0.29100000000000004},
#  'diagnosis': {'min': 0.0, 'max': 1.0}}
